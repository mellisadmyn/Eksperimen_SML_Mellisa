# %% [markdown]
# # **1. Perkenalan Dataset**

# %% [markdown]
# ##### 📊 **Dataset Overview**
# The Sleep Health and Lifestyle Dataset terdiri dari 400 baris dan 13 kolom, yang mencakup berbagai variabel terkait kebiasaan tidur dan aktivitas harian. Dataset ini memuat informasi seperti gender, age, occupation, sleep duration, quality of sleep, physical activity level, stress levels, BMI category, blood pressure, heart rate, daily steps, and the presence or absence of sleep disorders.
#
# Dataset ini diperoleh dari Kaggle dan dapat diakses melalui tautan berikut:
#
# 🔗 [Sleep Health and Lifestyle Dataset – Kaggle](https://www.kaggle.com/datasets/uom190346a/sleep-health-and-lifestyle-dataset)

# %% [markdown]
# ##### 🧾 **Dataset Columns**
#
# | Kolom                                | Deskripsi                                                                                     |
# |-------------------------------------|-----------------------------------------------------------------------------------------------|
# | **Person ID**                       | Identitas unik untuk setiap individu.                                                         |
# | **Gender**                          | Jenis kelamin individu (Laki-laki / Perempuan).                                               |
# | **Age**                             | Usia individu dalam tahun.                                                                    |
# | **Occupation**                      | Pekerjaan atau profesi individu.                                                              |
# | **Sleep Duration (hours)**          | Jumlah jam tidur per hari.                                                                    |
# | **Quality of Sleep (1–10)**         | Skor subjektif kualitas tidur, dalam skala 1 (tidak berkualitas) sampai 10 (sangat berkualitas).                                       |
# | **Physical Activity (minutes/day)** | Durasi aktivitas fisik harian dalam menit.                                                    |
# | **Stress Level (1–10)**             | Skor subjektif tingkat stres, dalam skala 1 (tidak stress) sampai 10 (sangat stress).                                        |
# | **BMI Category**                    | Kategori indeks massa tubuh (Contoh: Underweight, Normal, Overweight).                        |
# | **Blood Pressure**                  | Tekanan darah, ditunjukkan dalam format sistolik/diastolik.                                  |
# | **Heart Rate (bpm)**                | Detak jantung saat istirahat, dalam denyut per menit.                                         |
# | **Daily Steps**                     | Jumlah langkah kaki yang diambil per hari.                                                    |
# | **Sleep Disorder**                  | Jenis gangguan tidur yang dialami:<br>• **No Issue**: Tidak ada gangguan tidur.<br>• **Insomnia**: Kesulitan tidur atau sering terbangun.<br>• **Sleep Apnea**: Terhentinya napas saat tidur. |

# %% [markdown]
# ##### **Download Dataset**

# %%
# !kaggle datasets download -d uom190346a/sleep-health-and-lifestyle-dataset -p ../dataset_raw
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uom190346a/sleep-health-and-lifestyle-dataset
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# 100%|██████████| 2.54k/2.54k [00:00<?, ?B/s]

# %% [markdown]
# # **2. Import Library**

# %% [markdown]
# Pada tahap ini, Anda perlu mengimpor beberapa pustaka (library) Python yang dibutuhkan untuk analisis data dan pembangunan model machine learning atau deep learning.

# %%
import os
import zipfile
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **3. Memuat Dataset**

# %% [markdown]
# ##### **Extract and Load Dataset**

# %%
dataset_dir = "../dataset_raw"
zip_path    = os.path.join(dataset_dir, "sleep-health-and-lifestyle-dataset.zip")

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(dataset_dir)

# %%
csv_path    = "../dataset_raw/Sleep_health_and_lifestyle_dataset.csv"
data        = pd.read_csv(csv_path)

data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %% [markdown]
# ##### **Informasi Dataset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %% [markdown]
# # **4. Exploratory Data Analysis (EDA)**
#
# Pada tahap ini, Anda akan melakukan **Exploratory Data Analysis (EDA)** untuk memahami karakteristik dataset.
#
# Tujuan dari EDA adalah untuk memperoleh wawasan awal yang mendalam mengenai data dan menentukan langkah selanjutnya dalam analisis atau pemodelan.

# %% [markdown]
# ##### **4.1 Statistik Deskriptif**
#
# Menampilkan Statistik Deskriptif untuk Semua Kolom (Termasuk Kategorikal)

# %%
data.describe(include='all').T
# Out:
#                          count unique          top freq        mean  \
# Person ID                374.0    NaN          NaN  NaN       187.5
# Gender                     374      2         Male  189         NaN
# Age                      374.0    NaN          NaN  NaN   42.184492
# Occupation                 374     11        Nurse   73         NaN
# Sleep Duration           374.0    NaN          NaN  NaN    7.132086
# Quality of Sleep         374.0    NaN          NaN  NaN    7.312834
# Physical Activity Level  374.0    NaN          NaN  NaN   59.171123
# Stress Level             374.0    NaN          NaN  NaN    5.385027
# BMI Category               374      4       Normal  195         NaN
# Blood Pressure             374     25       130/85   99         NaN
# Heart Rate               374.0    NaN          NaN  NaN   70.165775
# Daily Steps              374.0    NaN          NaN  NaN  6816.84492
# Sleep Disorder             155      2  Sleep Apnea   78         NaN
#
# ...

# %% [markdown]
# **Kolom Numerik:**
#
# 1. **Age (Umur):**
#
#    * Rata-rata: 42.18 tahun
#    * Rentang: 27 – 59 tahun
#    * Distribusi tampak cukup tersebar dengan standar deviasi 8.67.
#
# 2. **Sleep Duration (Durasi Tidur):**
#
#    * Rata-rata: 7.13 jam
#    * Kisaran: 5.8 – 8.5 jam
#    * Sebagian besar orang tidur sekitar 7-7.2 jam (median).
#
# 3. **Quality of Sleep (Kualitas Tidur):**
#
#    * Rata-rata: 7.31 (dari skala 1–10)
#    * Distribusi cenderung positif dimulai dari 4 dengan nilai maksimal 9.
#
# 4. **Physical Activity Level:**
#
#    * Rata-rata: 59.17 menit
#    * Distribusi berkisar dari 30 hingga 90 menunjukkan variasi cukup besar dalam aktivitas fisik.
#
# 5. **Stress Level:**
#
#    * Rata-rata: 5.39 (dari skala 1-10).
#    * Distribusi dimulai dari 3 dan maksimal di skala 8.
#
# 6. **Heart Rate:**
#
#    * Rata-rata: 70.17 bpm, cukup sehat
#    * Distribusi cukup normal (min: 65, max: 86)
#
# 7. **Daily Steps (Langkah Harian):**
#
#    * Rata-rata: 6816 langkah
#    * Standar deviasi sangat tinggi (1617), menunjukkan variasi besar antar individu.
#    * Rentang: 3.000 – 10.000 langkah
#
#
# **Kolom Kategorikal:**
#
# 1. **Gender:**
#
#    * 2 kategori: Male dan Female
#    * Male paling sering muncul (189 dari 374)
#
# 2. **Occupation:**
#
#    * 11 jenis pekerjaan, dengan "Nurse" paling umum (73 orang)
#
# 3. **BMI Category:**
#
#    * 4 kategori, "Normal" paling banyak (195 orang)
#
# 4. **Blood Pressure:**
#
#    * 25 kombinasi nilai, "130/85" paling umum (99 orang)
#
# 5. **Sleep Disorder:**
#
#    * Hanya ada pada 155 dari 374 orang (berarti banyak missing value, perlu adanya pengecekan kembali)
#    * Dua kategori, paling umum "Sleep Apnea" (78 orang)
#
#
# ❗ **Insight yang didapatkan:**
#
# * **Kolom `Sleep Disorder` memiliki banyak missing values** (hanya 155/374 terisi), perlu diimputasi atau dianalisis lebih lanjut.
# * **Variasi besar** dalam `Blood Pressure` dan `Occupation` bisa menjadi fitur penting jika digunakan untuk prediksi.
# * Kolom seperti `Stress Level` dan `Physical Activity Level` dapat dibandingkan terhadap `Quality of Sleep` untuk korelasi lebih lanjut.

# %% [markdown]
# ##### **4.2 Cek Missing Value**
#
# Pemeriksaan nilai yang hilang penting untuk memastikan kualitas data pada tahap selanjutnya

# %%
data.isnull().sum()
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %% [markdown]
# ❗ **Insight yang didapatkan:**
#
# * Nilai NaN pada kolom Sleep Disorder bukanlah data hilang, melainkan merepresentasikan responden tanpa gangguan tidur (kategori "No Issue").
# * Hal ini penting untuk ditangani dengan benar pada tahap preprocessing nanti, misalnya dengan mengganti NaN menjadi string 'No Issue' agar tidak dianggap sebagai missing value.

# %% [markdown]
# ##### **4.3 Cek Data Duplicate**
#
# Duplikasi data dapat menyebabkan bias dalam analisis dan hasil model. Oleh karena itu, penting untuk memeriksa dan menangani baris yang duplikat dalam dataset.

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Mengecek duplikat dengan mengecualikan kolom 'Person ID'
duplikat = data.duplicated(subset=data.columns.difference(['Person ID']), keep=False)

# Menampilkan jumlah + baris total duplikat
print(f"Total data duplikat (tanpa memperhitungkan 'Person ID'): {duplikat.sum()}")
data[duplikat].head()
# Out:
# Total data duplikat (tanpa memperhitungkan 'Person ID'): 320
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
# 7          8   Male   29                Doctor             7.8
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
# 7                 7                       75             6       Normal
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# ...

# %% [markdown]
# ❗ **Insight yang didapatkan:**
#
# * Saat dilakukan pengecekan terhadap seluruh kolom, tidak ditemukan data duplikat.
# * Namun, setelah dilakukan pengecekan dengan mengecualikan kolom Person ID, yang bersifat unik dan berpotensi menyembunyikan duplikasi pada informasi lainnya, terlihat beberapa data yang sama. Duplikasi data tersebut akan ditelusuri lebih lanjut setelah proses pembersihan data pada tahap *'Data Preprocessing'*

# %% [markdown]
# ##### **4.4 Cek Unique Value**
#
# Mengetahui jumlah nilai unik dalam setiap kolom penting untuk memahami distribusi data dan mendeteksi kolom yang mungkin memiliki masalah seperti data duplikat tersembunyi, entri tidak konsisten, atau nilai yang seharusnya dikelompokkan.

# %%
for col in data.select_dtypes(include=['object']).columns:
    if data[col].nunique(dropna=False) <= 30:
        # Ganti NaN dengan string 'NaN' untuk plotting
        temp = data[col].fillna('NaN')

        plt.figure(figsize=(9, 6))
        ax = sns.countplot(x=temp, order=temp.value_counts().index)

        plt.title(f'Distribusi Kategori: {col}')
        plt.xticks(rotation=45)

        # Tambahkan label angka (sebagai integer)
        for p in ax.patches:
            height = p.get_height()
            ax.annotate(f'{int(height)}',  # <-- tampilkan sebagai int
                        (p.get_x() + p.get_width() / 2., height), 
                        ha='center', va='bottom', fontsize=9)

        plt.tight_layout()
        plt.show()

# %% [markdown]
# ❗ **Insight yang didapatkan:**
#
# * Pada kolom `BMI Category` seharusnya hanya terdapat tiga kategori: Normal, Overweight, dan Obese. Namun, ditemukan kategori Normal weight yang tidak konsisten. Nilai ini dapat ditangani pada tahap Data Preprocessing dengan mengonversinya ke Normal, jika nilainya sesuai dengan rentang BMI kategori tersebut.
# * Pada kolom `Blood Pressure` dapat dilakukan feature engineering di tahap Data Preprocessing untuk memisahkan nilai upper (sistolik) dan lower (diastolik) dari nilai tekanan darah secara keseluruhan, untuk memberikan insight yang lebih mendalam.
# * Nilai `NaN` pada kolom `Sleep Disorder` menunjukkan bahwa individu tersebut tidak mengalami gangguan tidur (None), sebagaimana yang telah dibahas sebelumnya.
# * Insight lainnya dapat digali lebih dalam, seperti proporsi antara pria dan wanita yang hampir seimbang, pekerjaan di bidang kesehatan memiliki presentase tertinggi, dll. Namun, perlu diperhatikan bahwa data yang ada masih mengandung duplikasi dan belum dibersihkan. Oleh karena itu, insight tersebut akan lebih akurat dan komprehensif setelah proses pembersihan data pada tahap "Data Preprocessing."

# %% [markdown]
# ##### **4.5 Cek Outliers**
#
# Menggunakan boxplot untuk memvisualisasikan distribusi data dan mendeteksi outlier. Outlier teridentifikasi jika titik data berada di luar whiskers.

# %%
numerical_columns = [x for x in data.select_dtypes(include='number').columns if x != 'Person ID']

plt.figure(figsize=(12, 6))
for i, col in enumerate(numerical_columns):
    plt.subplot(2, 4, i + 1)
    sns.boxplot(y=data[col])
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# ❗ **Insight yang didapatkan:**
#
# * Outlier hanya ditemukan pada Heart Rate, dengan beberapa nilai di atas 80 bpm yang berada di luar sebaran umum dalam dataset ini. Namun, nilai tersebut masih tergolong wajar dan masuk akal, mengingat detak jantung normal orang dewasa berkisar antara 60–100 bpm.
# * Pada Age, Sleep Duration, Quality of Sleep, Physical Activity Level, Stress Level, dan Daily Steps, distribusi data berada dalam rentang normal tanpa adanya nilai ekstrem yang menyimpang.

# %% [markdown]
# # **5. Data Preprocessing**

# %% [markdown]
# Pada tahap ini, data preprocessing adalah langkah penting untuk memastikan kualitas data sebelum digunakan dalam model machine learning.
#
# Jika Anda menggunakan data teks, data mentah sering kali mengandung nilai kosong, duplikasi, atau rentang nilai yang tidak konsisten, yang dapat memengaruhi kinerja model. Oleh karena itu, proses ini bertujuan untuk membersihkan dan mempersiapkan data agar analisis berjalan optimal.
#
# Berikut adalah tahapan-tahapan yang bisa dilakukan, tetapi **tidak terbatas** pada:
# 1. Menghapus atau Menangani Data Kosong (Missing Values)
# 2. Menghapus Data Duplikat
# 3. Normalisasi atau Standarisasi Fitur
# 4. Deteksi dan Penanganan Outlier
# 5. Encoding Data Kategorikal
# 6. Binning (Pengelompokan Data)
#
# Cukup sesuaikan dengan karakteristik data yang kamu gunakan yah. Khususnya ketika kami menggunakan data tidak terstruktur.

# %% [markdown]
# ##### **5.1 Rename Column**
#
# Pada tahap ini, dilakukan penyalinan data ke dalam variabel baru data_clean untuk menjaga data asli tetap utuh. Kemudian, seluruh nama kolom diubah menjadi huruf kecil dan spasi diganti dengan garis bawah (_), agar lebih konsisten dan mudah digunakan dalam analisis selanjutnya.

# %%
data_clean = data.copy()

data_clean.columns = data_clean.columns.str.lower().str.replace(' ', '_')
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   person_id                374 non-null    int64
#  1   gender                   374 non-null    object
#  2   age                      374 non-null    int64
#  3   occupation               374 non-null    object
#  4   sleep_duration           374 non-null    float64
#  5   quality_of_sleep         374 non-null    int64
#  6   physical_activity_level  374 non-null    int64
#  7   stress_level             374 non-null    int64
#  8   bmi_category             374 non-null    object
#  9   blood_pressure           374 non-null    object
#  10  heart_rate               374 non-null    int64
#  11  daily_steps              374 non-null    int64
#  12  sleep_disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %% [markdown]
# ##### **5.2 Drop Irrelevant Column**
#
# Kolom yang dianggap tidak relevan atau tidak dibutuhkan untuk analisis lebih lanjut akan dihapus dari dataset.

# %%
data_clean.drop(columns=['person_id'], inplace=True)
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   gender                   374 non-null    object
#  1   age                      374 non-null    int64
#  2   occupation               374 non-null    object
#  3   sleep_duration           374 non-null    float64
#  4   quality_of_sleep         374 non-null    int64
#  5   physical_activity_level  374 non-null    int64
#  6   stress_level             374 non-null    int64
#  7   bmi_category             374 non-null    object
#  8   blood_pressure           374 non-null    object
#  9   heart_rate               374 non-null    int64
#  10  daily_steps              374 non-null    int64
#  11  sleep_disorder           155 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 35.2+ KB

# %% [markdown]
# ##### **5.3 Handling Missing Values**
#
# Langkah ini bertujuan untuk menangani data yang hilang (missing values) pada kolom sleep_disorder, dengan cara mengisi **nilai kosong (NaN)** menggunakan label **"No Issue"**. Hal ini diasumsikan bahwa jika tidak ada catatan gangguan tidur, maka individu tersebut tidak memiliki masalah tidur.

# %%
# Mengisi missing value pada kolom 'sleep_disorder' dengan 'No Issue'
data_clean['sleep_disorder'] = data_clean['sleep_disorder'].fillna('No Issue')
data_clean['sleep_disorder'].isnull().sum()
# Out:
# np.int64(0)

# %%
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   gender                   374 non-null    object
#  1   age                      374 non-null    int64
#  2   occupation               374 non-null    object
#  3   sleep_duration           374 non-null    float64
#  4   quality_of_sleep         374 non-null    int64
#  5   physical_activity_level  374 non-null    int64
#  6   stress_level             374 non-null    int64
#  7   bmi_category             374 non-null    object
#  8   blood_pressure           374 non-null    object
#  9   heart_rate               374 non-null    int64
#  10  daily_steps              374 non-null    int64
#  11  sleep_disorder           374 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 35.2+ KB

# %% [markdown]
# ##### **5.4 Handling Incorrect Values**
#
# Langkah ini bertujuan untuk menangani nilai yang tidak konsisten dalam dataset.Pada kolom BMI Category, seharusnya hanya ada tiga kategori: Normal, Overweight, dan Obese. Namun, ditemukan nilai Normal weight yang tidak konsisten. Nilai ini dapat dikonversi ke Normal, jika sesuai dengan rentang BMI yang relevan.

# %%
data_clean[data_clean.bmi_category == 'Normal'].describe()
# Out:
#               age  sleep_duration  quality_of_sleep  physical_activity_level  \
# count  195.000000      195.000000        195.000000               195.000000
# mean    38.482051        7.393846          7.661538                57.692308
# std      7.561666        0.732080          0.946130                21.896139
# min     28.000000        6.000000          6.000000                30.000000
# 25%     32.000000        7.150000          7.000000                30.000000
# 50%     37.000000        7.500000          8.000000                60.000000
# 75%     42.000000        7.800000          8.000000                75.000000
# max     54.000000        8.500000          9.000000                90.000000
#
#        stress_level  heart_rate   daily_steps
# count    195.000000  195.000000    195.000000
# mean       5.128205   68.728205   6887.179487
# std        1.605074    2.293643   1372.630008
# min        3.000000   65.000000   5000.000000
# ...

# %%
data_clean[data_clean.bmi_category == 'Normal Weight'].describe()
# Out:
#              age  sleep_duration  quality_of_sleep  physical_activity_level  \
# count  21.000000       21.000000         21.000000                21.000000
# mean   38.380952        7.333333          7.428571                60.333333
# std     7.921339        0.585093          1.398979                16.758083
# min    29.000000        6.400000          5.000000                35.000000
# 25%    32.000000        6.900000          7.000000                50.000000
# 50%    37.000000        7.300000          8.000000                60.000000
# 75%    40.000000        7.800000          8.000000                70.000000
# max    56.000000        8.200000          9.000000                90.000000
#
#        stress_level  heart_rate   daily_steps
# count     21.000000   21.000000     21.000000
# mean       5.190476   71.285714   6766.666667
# std        1.503963    4.616740   1722.304658
# min        3.000000   65.000000   4000.000000
# 25%        4.000000   68.000000   6000.000000
# ...

# %% [markdown]
# ❗ **Insight yang didapatkan:**
#
# * Datanya seragam, maka kelas "Normal Weight" akan diubah menjadi "Normal"

# %%
data_clean['bmi_category'] = data_clean['bmi_category'].replace('Normal Weight', 'Normal')
data_clean['bmi_category'].value_counts()
# Out:
# bmi_category
# Normal        216
# Overweight    148
# Obese          10
# Name: count, dtype: int64

# %%
category_order = ['Normal', 'Overweight', 'Obese']

data_clean['bmi_category'] = pd.Categorical(data_clean['bmi_category'], categories=category_order, ordered=True)
data_clean['bmi_category'].dtype
# Out:
# CategoricalDtype(categories=['Normal', 'Overweight', 'Obese'], ordered=True, categories_dtype=object)

# %% [markdown]
# ##### **5.5 Feature Engineering**
#
# Pada langkah ini, tujuan utamanya adalah untuk memisahkan nilai tekanan darah menjadi dua komponen utama, yaitu tekanan darah sistolik (upper) dan diastolik (lower). Pemisahan ini bertujuan untuk memberikan wawasan yang lebih mendalam dan analisis yang lebih terfokus pada kedua komponen tersebut, yang pada gilirannya dapat membantu dalam pembuatan model yang lebih akurat.
#
# Setelah memisahkan nilai tekanan darah antara sistolik dan diastolik, kita juga dapat mengidentifikasi peluang untuk membuat fitur baru. Salah satunya adalah dengan mengategorikan tekanan darah seseorang sebagai "normal" atau "tidak normal" berdasarkan nilai sistolik dan diastolik yang dimilikinya. Fitur ini dapat digunakan untuk analisis lebih lanjut dan meningkatkan prediktabilitas model. Source: https://www.heart.org/en/health-topics/high-blood-pressure/understanding-blood-pressure-readings

# %%
data_clean = pd.concat([data_clean, data_clean['blood_pressure'].str.split('/', expand=True)], axis=1).drop('blood_pressure', axis=1)
data_clean = data_clean.rename(columns={0: 'blood_pressure_upper', 1: 'blood_pressure_lower'})
data_clean['blood_pressure_upper'] = data_clean['blood_pressure_upper'].astype(int)
data_clean['blood_pressure_lower'] = data_clean['blood_pressure_lower'].astype(int)

data_clean.head()
# Out:
#   gender  age            occupation  sleep_duration  quality_of_sleep  \
# 0   Male   27     Software Engineer             6.1                 6
# 1   Male   28                Doctor             6.2                 6
# 2   Male   28                Doctor             6.2                 6
# 3   Male   28  Sales Representative             5.9                 4
# 4   Male   28  Sales Representative             5.9                 4
#
#    physical_activity_level  stress_level bmi_category  heart_rate  \
# 0                       42             6   Overweight          77
# 1                       60             8       Normal          75
# 2                       60             8       Normal          75
# 3                       30             8        Obese          85
# 4                       30             8        Obese          85
#
#    daily_steps sleep_disorder  blood_pressure_upper  blood_pressure_lower
# ...

# %%
def categorize_blood_pressure(systolic, diastolic):
    if systolic < 90 or diastolic < 60:
        return "Low"
    elif 90 <= systolic < 120 and diastolic < 80:
        return "Normal"
    elif 120 <= systolic < 130 and diastolic < 80:
        return "Elevated"
    elif 130 <= systolic < 140 or 80 <= diastolic < 90:
        return "Hypertension Stage 1"
    elif 140 <= systolic < 180 or 90 <= diastolic < 120:
        return "Hypertension Stage 2"
    else:
        return "Hypertensive Crisis"

data_clean['blood_pressure_category'] = data_clean.apply(lambda row: categorize_blood_pressure(row['blood_pressure_upper'], row['blood_pressure_lower']), axis=1)
data_clean['blood_pressure_category'].value_counts()
# Out:
# blood_pressure_category
# Hypertension Stage 1    261
# Hypertension Stage 2     71
# Normal                   41
# Elevated                  1
# Name: count, dtype: int64

# %%
category_order = ["Low", "Normal", "Elevated", "Hypertension Stage 1", "Hypertension Stage 2", "Hypertensive Crisis"]

data_clean['blood_pressure_category'] = pd.Categorical(data_clean['blood_pressure_category'], categories=category_order, ordered=True)
data_clean['blood_pressure_category'].dtype
# Out:
# CategoricalDtype(categories=['Low', 'Normal', 'Elevated', 'Hypertension Stage 1',
#                   'Hypertension Stage 2', 'Hypertensive Crisis'],
# , ordered=True, categories_dtype=object)

# %%
data_clean.head()
# Out:
#   gender  age            occupation  sleep_duration  quality_of_sleep  \
# 0   Male   27     Software Engineer             6.1                 6
# 1   Male   28                Doctor             6.2                 6
# 2   Male   28                Doctor             6.2                 6
# 3   Male   28  Sales Representative             5.9                 4
# 4   Male   28  Sales Representative             5.9                 4
#
#    physical_activity_level  stress_level bmi_category  heart_rate  \
# 0                       42             6   Overweight          77
# 1                       60             8       Normal          75
# 2                       60             8       Normal          75
# 3                       30             8        Obese          85
# 4                       30             8        Obese          85
#
#    daily_steps sleep_disorder  blood_pressure_upper  blood_pressure_lower  \
# ...

# %% [markdown]
# ##### **5.6 Handling Duplicated Data**
#
# Pada langkah ini, tujuan utamanya adalah untuk mengidentifikasi dan menghapus baris data yang terduplikasi dalam dataset.

# %%
data_clean.duplicated().sum()
# Out:
# np.int64(242)

# %%
data_clean.drop_duplicates(inplace=True)
data_clean.duplicated().sum()
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 132 entries, 0 to 366
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   gender                   132 non-null    object
#  1   age                      132 non-null    int64
#  2   occupation               132 non-null    object
#  3   sleep_duration           132 non-null    float64
#  4   quality_of_sleep         132 non-null    int64
#  5   physical_activity_level  132 non-null    int64
#  6   stress_level             132 non-null    int64
#  7   bmi_category             132 non-null    category
#  8   heart_rate               132 non-null    int64
#  9   daily_steps              132 non-null    int64
#  10  sleep_disorder           132 non-null    object
#  11  blood_pressure_upper     132 non-null    int64
#  12  blood_pressure_lower     132 non-null    int64
#  13  blood_pressure_category  132 non-null    category
# ...

# %%
data_clean
# Out:
#      gender  age            occupation  sleep_duration  quality_of_sleep  \
# 0      Male   27     Software Engineer             6.1                 6
# 1      Male   28                Doctor             6.2                 6
# 3      Male   28  Sales Representative             5.9                 4
# 5      Male   28     Software Engineer             5.9                 4
# 6      Male   29               Teacher             6.3                 6
# ..      ...  ...                   ...             ...               ...
# 358  Female   59                 Nurse             8.0                 9
# 359  Female   59                 Nurse             8.1                 9
# 360  Female   59                 Nurse             8.2                 9
# 364  Female   59                 Nurse             8.0                 9
# 366  Female   59                 Nurse             8.1                 9
#
#      physical_activity_level  stress_level bmi_category  heart_rate  \
# ...

# %%
data_clean.to_csv("dataset_preprocessing/sleep_health_and_lifestyle_dataset_clean.csv", index=False)
